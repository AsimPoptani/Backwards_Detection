# %%
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import math
from PIL import Image
import random

# %%
# !pip3 install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.2.0-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in ./venv2/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in ./venv2/lib/python3.8/site-packages (from pandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.3 in ./venv2/lib/python3.8/site-packages (from pandas) (2020.4)
# Requirement already satisfied: six>=1.5 in ./venv2/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from utils import movie_images_to_dict

# %%
trainning_folder="trainning_images"
test_folder="test_images"

# %%
trainning_data_set=[]
test_data_set=[]
# Loop through trainning images
for index in range(3):
    trainning_data_set.append(pd.DataFrame(movie_images_to_dict.get_images_to_dict(f'/media/Data/backwards_detection/trainning_images/{index}/')).to_numpy())
# Loop through test images
for index in range(1):
    test_data_set.append(pd.DataFrame(movie_images_to_dict.get_images_to_dict(f'/media/Data/backwards_detection/test_images/{index}/')).to_numpy())

# %%
pd.DataFrame(trainning_data_set[0])
# Out:
#                    0                                                  1    2  \
# 0       00000001.png  /media/Data/backwards_detection/trainning_imag...  800
# 1       00000002.png  /media/Data/backwards_detection/trainning_imag...  800
# 2       00000003.png  /media/Data/backwards_detection/trainning_imag...  800
# 3       00000004.png  /media/Data/backwards_detection/trainning_imag...  800
# 4       00000005.png  /media/Data/backwards_detection/trainning_imag...  800
# ...              ...                                                ...  ...
# 138370  00138371.png  /media/Data/backwards_detection/trainning_imag...  800
# 138371  00138372.png  /media/Data/backwards_detection/trainning_imag...  800
# 138372  00138373.png  /media/Data/backwards_detection/trainning_imag...  800
# 138373  00138374.png  /media/Data/backwards_detection/trainning_imag...  800
# 138374  00138375.png  /media/Data/backwards_detection/trainning_imag...  800
#
#            3
# 0       1280
# 1       1280
# 2       1280
# 3       1280
# 4       1280
# ...      ...
# 138370  1280
# 138371  1280
# 138372  1280
# 138373  1280
# 138374  1280
#
# [138375 rows x 4 columns]

# %%
from typing import List, Tuple, Union
def shape(ndarray: Union[List, float]) -> Tuple[int, ...]:
    if isinstance(ndarray, list):
        # More dimensions, so make a recursive call
        outermost_size = len(ndarray)
        row_shape = shape(ndarray[0])
        return (outermost_size, *row_shape)
    else:
        # No more dimensions, so we're done
        return ()

# %%
# conversion methods 
# will generate a array of x frames
def every_x_frame(data,x=5):
    size=data.shape[0]
    left_over=size%x
    n_times=math.floor(size/x)
    data=data[:-left_over,:]
    split=np.split(data,n_times)
    return split

def negative_frames(data,x):
    data_to_be_shuffled=data.copy()
    
    np.random.shuffle(data_to_be_shuffled)
    random=every_x_frame(data_to_be_shuffled,x)
    flip=every_x_frame(np.flip(data,axis=0),x)
    return flip+random

# generates positive and negative tests for x frames
def gen_every_x_frames(data,x=5):
    data=data.copy()
    positive=every_x_frame(data,x)
    negative=negative_frames(data,x)
    return [positive,negative]

# generates positive and negative tests for x frames
def gen_every_x_frames_skip(data,step=2,x=5):
    data=data.copy()
    data=data[::step]
    return gen_every_x_frames(data,x)

# %%
NUMBER_OF_IMAGES=5
def trainning_data_set_gen():
    data_set_pos=[]
    data_set_neg=[]
    for trainning in trainning_data_set:
        # generate cases for NUMBER_OF_IMAGES images and a skip of 2
        positive, negative=gen_every_x_frames_skip(trainning,x=NUMBER_OF_IMAGES)
        data_set_pos=data_set_pos+positive
        data_set_neg=data_set_neg+negative
    return data_set_pos,data_set_neg
def test_data_set_gen():
    data_set_pos=[]
    data_set_neg=[]
    for test in test_data_set:
        # generate cases for 5 images and a skip of 2
        positive, negative=gen_every_x_frames_skip(test, x=NUMBER_OF_IMAGES)
        data_set_pos=data_set_pos+positive
        data_set_neg=data_set_neg+negative
    return data_set_pos,data_set_neg

def pick_x_amount(data,x):
    return random.sample(data,x)

def open_images_prep_keras(posData, negData, limit, random=True):
    # take positive and negative data and limit
    if random:
        posData=pick_x_amount(posData,limit)
        negData=pick_x_amount(negData,limit)
    else:
        posData=posData[0:limit]
        negData=negData[0:limit]
    # image_paths Y
    data_set=[]
    for pos_images in posData:
        image_paths=[]
        for image in pos_images:
            image_paths.append(image[1]+image[0])
        xy=[image_paths,1]
        data_set.append(xy)
    for neg_images in negData:
        image_paths=[]
        for image in neg_images:
            image_paths.append(image[1]+image[0])
        xy=[image_paths,0]
        data_set.append(xy)
    data_set=np.array(data_set)
    np.random.shuffle(data_set)
    for data in data_set:
        image_data={}
        for i,image_path in enumerate(data[0]):
            image_data[f"input_{i}"]=np.array(Image.open(image_path),dtype=np.float32)/255
        yield (image_data,np.array(data[1],dtype=np.int8))

def trainning_images_gen():
    keras_trainning_data_set_pos, keras_trainning_data_set_neg= trainning_data_set_gen()
    return open_images_prep_keras(keras_trainning_data_set_pos,keras_trainning_data_set_neg,10000)

def test_images_gen():
    keras_test_data_set_pos, keras_test_data_set_neg= test_data_set_gen()
    return open_images_prep_keras(keras_test_data_set_pos,keras_test_data_set_neg,1000)

# %%
# next(trainning_images_gen())
trainning_data_set_gen()[1]
# Out:
# [array([['00138375.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138373.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138371.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138369.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138367.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138365.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138363.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138361.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138359.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138357.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138355.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138353.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138351.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138349.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138347.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138345.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138343.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138341.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138339.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138337.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138335.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138333.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138331.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138329.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138327.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138325.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138323.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138321.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138319.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138317.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138315.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138313.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138311.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138309.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138307.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138305.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138303.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138301.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138299.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138297.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138295.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138293.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138291.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138289.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138287.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138285.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138283.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138281.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138279.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138277.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138275.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138273.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138271.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138269.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138267.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138265.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138263.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138261.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138259.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138257.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138255.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138253.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138251.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138249.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138247.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138245.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138243.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138241.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138239.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138237.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138235.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138233.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138231.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138229.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138227.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138225.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138223.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138221.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138219.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138217.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138215.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138213.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138211.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138209.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138207.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138205.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138203.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138201.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138199.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138197.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138195.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138193.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138191.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138189.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138187.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138185.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138183.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138181.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138179.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138177.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138175.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138173.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138171.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138169.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138167.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138165.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138163.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138161.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138159.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138157.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138155.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138153.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138151.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138149.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138147.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138145.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138143.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138141.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138139.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138137.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138135.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138133.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138131.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138129.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138127.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138125.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138123.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138121.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138119.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138117.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138115.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138113.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138111.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138109.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138107.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138105.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138103.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138101.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138099.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138097.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138095.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138093.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138091.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138089.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138087.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138085.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138083.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138081.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138079.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138077.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138075.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138073.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138071.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138069.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138067.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00138065.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138063.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138061.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00138059.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00
png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128507.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128505.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128503.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128501.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128499.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128497.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128495.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128493.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128491.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128489.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128487.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128485.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128483.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128481.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128479.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128477.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128475.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128473.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128471.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128469.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128467.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128465.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128463.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128461.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128459.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128457.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128455.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128453.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128451.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128449.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128447.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128445.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128443.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128441.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128439.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128437.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128435.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128433.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128431.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128429.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128427.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128425.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128423.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128421.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128419.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128417.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128415.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128413.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128411.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128409.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128407.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128405.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128403.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128401.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128399.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128397.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128395.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128393.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128391.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128389.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128387.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  array([['00128385.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128383.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128381.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128379.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280],
#         ['00128377.png',
#          '/media/Data/backwards_detection/trainning_images/0/', 800, 1280]],
#        dtype=object),
#  ...]

# %%
x_gen_inputs={}
x_gen_inputs_shapes={}
for i in range(NUMBER_OF_IMAGES):
    x_gen_inputs[f"input_{i}"]=tf.float32
    x_gen_inputs_shapes[f"input_{i}"]=tf.TensorShape([800,1920,3])
xy_gen_inputs_output=(x_gen_inputs,tf.int8)
xy_gen_inputs_output_shape=(x_gen_inputs_shapes,tf.TensorShape([]))
trainning_images_gen_tensor=tf.data.Dataset.from_generator(
    trainning_images_gen,
    xy_gen_inputs_output,
    xy_gen_inputs_output_shape
    )

test_images_gen_tensor=tf.data.Dataset.from_generator(
    test_images_gen,
    xy_gen_inputs_output,
    xy_gen_inputs_output_shape
    )
training_dataset_with_batch_and_prefetch=trainning_images_gen_tensor.batch(20).prefetch(2)
test_dataset_with_batch_and_prefetch=test_images_gen_tensor.batch(20).prefetch(2)

# %%
# convert input to output
def start_of_cnn(i):
    image_input=tf.keras.layers.Input(shape=(800,1920,3),name=f"input_{i}")
    x=tf.keras.layers.Conv2D(filters=10,kernel_size=[2,2],activation='relu',padding='valid')(image_input)
    x=tf.keras.layers.MaxPooling2D()(x)
    x=tf.keras.layers.Dropout(.1)(x)
    x=tf.keras.layers.Conv2D(filters=20,kernel_size=[2,2],activation='relu',padding='valid')(x)
    x=tf.keras.layers.MaxPooling2D()(x)
    x=tf.keras.layers.Dropout(.1)(x)
    x=tf.keras.layers.Conv2D(filters=40,kernel_size=[2,2],activation='relu',padding='valid')(x)
    x=tf.keras.layers.MaxPooling2D()(x)
    x=tf.keras.layers.Dropout(.1)(x)
    x=tf.keras.layers.Conv2D(filters=80,kernel_size=[2,2],activation='relu',padding='valid')(x)
    x=tf.keras.layers.MaxPooling2D()(x)
    x=tf.keras.layers.Dropout(.1)(x)
    x=tf.keras.layers.Conv2D(filters=160,kernel_size=[2,2],activation='relu',padding='valid')(x)
    x=tf.keras.layers.MaxPooling2D()(x)
    x=tf.keras.layers.Dropout(.1)(x)
    x=tf.keras.layers.Conv2D(filters=320,kernel_size=[2,2],activation='relu',padding='valid')(x)
    x=tf.keras.layers.MaxPooling2D()(x)
    x=tf.keras.layers.Dropout(.1)(x)

    x=tf.keras.layers.Flatten()(x)
    # x=tf.keras.Model(inputs=image_input,outputs=x) #(None, 48, 118, 25) 
    return image_input,x
inputs=[]
combined_layers=[]
for i in range(NUMBER_OF_IMAGES):
    input_cnn, combined_layer = start_of_cnn(i)
    inputs.append(input_cnn)
    combined_layers.append(combined_layer)

combined=tf.keras.layers.concatenate(axis=1,inputs=combined_layers)
x=tf.keras.layers.Dense(20, activation="relu")(combined)
x=tf.keras.layers.Dense(20, activation="relu")(x)
x=tf.keras.layers.Dense(1, activation="softmax")(x)
x=tf.keras.Model(inputs=inputs,outputs=x)
x.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_0 (InputLayer)            [(None, 800, 1920, 3 0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 800, 1920, 3 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 800, 1920, 3 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 800, 1920, 3 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 800, 1920, 3 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 799, 1919, 10 130         input_0[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 799, 1919, 10 130         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 799, 1919, 10 130         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 799, 1919, 10 130         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 799, 1919, 10 130         input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 399, 959, 10) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 399, 959, 10) 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 399, 959, 10) 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 399, 959, 10) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 399, 959, 10) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 399, 959, 10) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 399, 959, 10) 0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 399, 959, 10) 0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 399, 959, 10) 0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 399, 959, 10) 0           max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 398, 958, 20) 820         dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 398, 958, 20) 820         dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 398, 958, 20) 820         dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 398, 958, 20) 820         dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 398, 958, 20) 820         dropout_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 199, 479, 20) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 199, 479, 20) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 199, 479, 20) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 199, 479, 20) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 199, 479, 20) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 199, 479, 20) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 199, 479, 20) 0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 199, 479, 20) 0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 199, 479, 20) 0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 199, 479, 20) 0           max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 198, 478, 40) 3240        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 198, 478, 40) 3240        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 198, 478, 40) 3240        dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 198, 478, 40) 3240        dropout_19[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 198, 478, 40) 3240        dropout_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 99, 239, 40)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 99, 239, 40)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 99, 239, 40)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 99, 239, 40)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 99, 239, 40)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 99, 239, 40)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 99, 239, 40)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 99, 239, 40)  0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 99, 239, 40)  0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 99, 239, 40)  0           max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 98, 238, 80)  12880       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 98, 238, 80)  12880       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 98, 238, 80)  12880       dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 98, 238, 80)  12880       dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 98, 238, 80)  12880       dropout_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 49, 119, 80)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 49, 119, 80)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 49, 119, 80)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 49, 119, 80)  0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 49, 119, 80)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 49, 119, 80)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 49, 119, 80)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 49, 119, 80)  0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 49, 119, 80)  0           max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 49, 119, 80)  0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 118, 160) 51360       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 48, 118, 160) 51360       dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 48, 118, 160) 51360       dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 48, 118, 160) 51360       dropout_21[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 48, 118, 160) 51360       dropout_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 24, 59, 160)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 24, 59, 160)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 24, 59, 160)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 24, 59, 160)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 24, 59, 160)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 59, 160)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 24, 59, 160)  0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 24, 59, 160)  0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 24, 59, 160)  0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 24, 59, 160)  0           max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 23, 58, 320)  205120      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 23, 58, 320)  205120      dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 23, 58, 320)  205120      dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 23, 58, 320)  205120      dropout_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 23, 58, 320)  205120      dropout_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 11, 29, 320)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 11, 29, 320)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 11, 29, 320)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 11, 29, 320)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 11, 29, 320)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 11, 29, 320)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 11, 29, 320)  0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 11, 29, 320)  0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 11, 29, 320)  0           max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 11, 29, 320)  0           max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 102080)       0           dropout_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 102080)       0           dropout_11[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 102080)       0           dropout_17[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 102080)       0           dropout_23[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 102080)       0           dropout_29[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 510400)       0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 20)           10208020    concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           420         dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            21          dense_1[0][0]
# ==================================================================================================
# Total params: 11,576,211
# Trainable params: 11,576,211
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
x.fit(training_dataset_with_batch_and_prefetch,validation_data=test_dataset_with_batch_and_prefetch)
# Out:
#      16/Unknown - 94s 6s/step - loss: 7.2434 - accuracy: 0.5250
